# %%
import tweepy
from tweepy import OAuthHandler, Stream, StreamListener

consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
tweets = api.home_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @imanbr: Setelah santri yang sudah menyebut nama nama Menteri Jokowi. Ternyata Adian juga sudah menebak hal ini https://t.co/yafxHNrzhZ
# Sri Mulyani adalah orang pertama yang dipanggil Jokowi di hari kedua "seleksi" menteri.
#
# https://t.co/eolgpP2B1Q
# Jadilah saksi sejarah perjalanan Kurator Paviliun Indonesia untuk Venice Architecture Biennale 2020 - di Hotel Morr… https://t.co/ZLvdEFnPwl
# Selamat untuk proposal yang telah terpilih menjadi finalis seleksi Kurator Venice Architecture Biennale 2020.
#
# Sete… https://t.co/tDymURHScA
# @wijayantea ok halo anya
# Lebih pinter lagi lah make internet, jgn kek orang kemaren sore baru akses internet. Malu sama bocil.
# Gravy-Stuffed Biscuits https://t.co/y0PhyYhuBZ
# Mobil listrik yang ramah lingkungan hadir sebagai respons untuk tantangan perubahan iklim 10 tahun mendatang. Salah… https://t.co/TynmBsXU3a
# りんごタルト🍎〜サクッと香ばしい♪〜 https://t.co/UqxYhcR8AV
# Gw denger lagu "kutukan" gloomy sunday yg terkenal lagu bundir biasa aja.
# ...

# %%
user_tweets = api.user_timeline(screen_name='jokowi', count=200, tweet_mode="extended")
for tweet in user_tweets:
    print(tweet._json)
# Out:
# {'created_at': 'Mon Oct 21 01:07:48 +0000 2019', 'id': 1186086650125807616, 'id_str': '1186086650125807616', 'full_text': 'Saya ingin para menteri terpilih adalah sosok yang inovatif, produktif, pekerja keras dan cepat. Sosok yang tidak terjebak rutinitas yang monoton.\n\nTugas kita bukan hanya membuat dan melaksanakan kebijakan, tetapi memastikan masyarakat menikmati pelayanan dan hasil pembangunan. https://t.co/RqUakMdSCX', 'truncated': False, 'display_text_range': [0, 278], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1186086642299203584, 'id_str': '1186086642299203584', 'indices': [279, 302], 'media_url': 'http://pbs.twimg.com/media/EHXThFsUcAAvLDY.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EHXThFsUcAAvLDY.jpg', 'url': 'https://t.co/RqUakMdSCX', 'display_url': 'pic.twitter.com/RqUakMdSCX', 'expanded_url': 'https://twitter.com/jokowi/status/1186086650125807616/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 
# ...

# %%
the_list = []
tweet_jokowi = api.user_timeline(screen_name='jokowi', count=200, tweet_mode="extended")
for tweet in tweet_jokowi:
    the_list.append(tweet._json)

# %%
import pandas
myData = pandas.DataFrame(the_list)
myData
# Out:
#                          created_at                   id               id_str  \
# 0    Mon Oct 21 01:07:48 +0000 2019  1186086650125807616  1186086650125807616
# 1    Sun Oct 20 14:46:46 +0000 2019  1185930364012777472  1185930364012777472
# 2    Sun Oct 20 10:42:36 +0000 2019  1185868915945033728  1185868915945033728
# 3    Sun Oct 20 02:47:37 +0000 2019  1185749380290080768  1185749380290080768
# 4    Sat Oct 19 03:03:31 +0000 2019  1185390993660530689  1185390993660530689
# ..                              ...                  ...                  ...
# 195  Wed Jul 10 10:42:09 +0000 2019  1148905239061225472  1148905239061225472
# 196  Wed Jul 10 02:57:45 +0000 2019  1148788368198606849  1148788368198606849
# 197  Tue Jul 09 12:03:39 +0000 2019  1148563364370472960  1148563364370472960
# 198  Mon Jul 08 12:07:05 +0000 2019  1148201837536763904  1148201837536763904
# 199  Sun Jul 07 12:40:18 +0000 2019  1147847810215075840  1147847810215075840
#
# ...

# %%
import datetime
import pandas
user_tweets_list = []

user_tweets = api.user_timeline(screen_name='AdjieSanPutro', count=200, tweet_mode="extended")
startDate = datetime.datetime(2019, 10, 22, 0, 0, 0)
endDate = datetime.datetime(2019, 10, 24, 0, 0, 0)
for tweet in user_tweets:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        user_tweets_list.append(tweet._json)
        
userData = pandas.DataFrame(user_tweets_list)
userData
# Out:
#                         created_at                   id               id_str  \
# 0   Wed Oct 23 13:23:08 +0000 2019  1186996477693874176  1186996477693874176
# 1   Wed Oct 23 13:00:20 +0000 2019  1186990740976656384  1186990740976656384
# 2   Wed Oct 23 12:29:12 +0000 2019  1186982904670253056  1186982904670253056
# 3   Wed Oct 23 12:28:44 +0000 2019  1186982788110548992  1186982788110548992
# 4   Wed Oct 23 09:42:14 +0000 2019  1186940885839183872  1186940885839183872
# 5   Wed Oct 23 09:37:02 +0000 2019  1186939578948538368  1186939578948538368
# 6   Wed Oct 23 08:59:40 +0000 2019  1186930174383624192  1186930174383624192
# 7   Wed Oct 23 08:16:19 +0000 2019  1186919266630549504  1186919266630549504
# 8   Wed Oct 23 08:13:06 +0000 2019  1186918456370724864  1186918456370724864
# 9   Wed Oct 23 05:30:04 +0000 2019  1186877426380484608  1186877426380484608
# 10  Wed Oct 23 01:17:18 +0000 2019  1186813818254422017  1186813818254422017
# ...

# %%
hashtags = ["#google", "#100DaysOfCode", "#python"]
hashtag_tweets = []

for hashtag in hashtags:
    for tweet in api.search(q=hashtag, lang="en", rpp=50, tweet_mode="extended"):
        hashtag_tweets.append(tweet._json)

hashtagData = pandas.DataFrame(hashtag_tweets)
hashtagData.to_csv("hashtag.csv")
hashtagData
